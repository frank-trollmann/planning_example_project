# %% [markdown]
# # A Star Test Experiment
#
# In this experiment we evaluate whether the coordinates we have annotated via graph layouting are usable to inform an A* search - and which coordinates are appropriate.
#
# For this purpose, we will run A* and Dijkstra on each created coordinate annotation to find out which of them is most suitable.

# %%
# correct working directory.
# This is necessary for imports because the notebook is not in the main folder of the project. 
if not "working_directory_corrected" in vars():
    # %cd ..
    working_directory_corrected = True


import pandas as pd

from evaluation.timed_experiment import Timed_Experiment
from algorithms.dijkstra import Dijkstra
from algorithms.a_star import A_Star


# load dataset
from data.dataset import Dataset
# Out:
# c:\Users\frank\Documents\Teaching\LU\Planning and Optimization LU - Material\Planning Example Project\planning_example_project\environment\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# c:\Users\frank\Documents\Teaching\LU\Planning and Optimization LU - Material\Planning Example Project\planning_example_project

# %% [markdown]
# ## Dataset
# This experiment is based on data generated with the script generate_coordinates. This script applies all algorithms identified in coordinate_annotation.ipynb to the graph and generates coordinates. It does so 5 times since in previous experiments we noted that the coordinates differ significantly from each other from run to run.
#
#
# While executing this script, we had to exclude some of the algorithms due to the following reasons:
# - kamada_kawai and mds ran into memory issues and could not be executed
# - davidson_harel and graphopt have not delivered a result within an hour of time. To keep the experiment manageable time-wise, they have been excluded based on this.
#
#
# After these exclusions, the following algorithms remained: auto, drl, fruchterman_reingold

# %% [markdown]
# ## Experiment 1 - Scale factor
#
# As discussed in coordinate_annotation.ipynb, some coordinates where extremely close together. To give A* a fair chance we would like to rectify this by scaling coordinates so that they are in similar maximal distances.
#
# **Procedure**
#
# The cell below loads the first coordinate set of each algorithm and prints the minimum and maximum x and y coordinates. From this we will determine scale factors as potenties of 10 to assure that both coordinates are at least 10000 apart.

# %%
from asyncio.windows_events import INFINITE


for algorithm_name in ["auto", "drl", "fruchterman_reingold"]:
    file_name = f"if_{algorithm_name}_1"

    # load and convert graph
    dataset = Dataset()
    graph = dataset.load_graph()
    dataset.convert_to_spatial(graph,file_name)

    # find min and max of coordinates
    min_x = min(graph.node_positions, key= lambda coord: coord[0])[0]
    max_x = max(graph.node_positions, key= lambda coord: coord[0])[0]
    min_y = min(graph.node_positions, key= lambda coord: coord[1])[1]
    max_y = max(graph.node_positions, key= lambda coord: coord[1])[1]

    print("\n" + algorithm_name)
    print(f"min_x: {min_x}, max_x: {max_x}, Distance: {max_x - min_x}")		
    print(f"min_y: {min_y}, max_y: {max_y}, Distance: {max_y - min_y}")
# Out:
# auto
# min_x: -979.9690551757812, max_x: 974.4048461914062, Distance: 1954.3739013671875
# min_y: -955.8806762695312, max_y: 950.1741333007812, Distance: 1906.0548095703125
#
# drl
# min_x: -962.9459228515625, max_x: 959.2142944335938, Distance: 1922.1602172851562
# min_y: -979.453125, max_y: 961.8577270507812, Distance: 1941.3108520507812
#
# fruchterman_reingold
# min_x: -258.30335937319484, max_x: 290.7462575501768, Distance: 549.0496169233716
# min_y: -276.3667291666116, max_y: 282.34564149108724, Distance: 558.7123706576988

# %% [markdown]
# **Conclusions:**
#
# From this experiment it seems like the the coordinates are already quite far apart and don't need to be changed much.
#
# We will apply the following scale factors:
# - auto: 10
# - drl: 10
# - fruchterman_reingold: 100

# %% [markdown]
# ## Experiment 2: Which coordinates are best?
#
# The goal of this experiment is to determine which coordinates perform best with A* and Dijkstra.
#
# **Procedure**
#
# In the below cell we run Dijkstra and A* with all 5 variants of the three layout algorithms. To have a comparison benchmark we also run them without coordinates.
#
# Each run will be comprised of 100 planning problems, all with the same seed.From each experiment we will collect the following data:
# - *average_time*: The average time they took to solve each problem.
# - *nr_extended*: The number of nodes that were extended.
# - *time per extension*: The average time required for one extension.
#
# We will also record these three values for failed and successfull runs.
#
# After running the experiments we will use these values to discuss the results.
# Specifically, we will use the average time to decide which dataset in which variation to select and compare against other algorithms later.

# %%
algorithm_names = [None, "auto", "drl", "fruchterman_reingold"]
scale_factors = [0, 10,10,100]
planners = [Dijkstra, A_Star] 

for index in range(len(algorithm_names)):
    algorithm_name = algorithm_names[index]	
    scale_factor = scale_factors[index]	
    
    for variation in range(5):
        file_name = f"if_{algorithm_name}_{variation}"
        dataset = Dataset()
        graph = dataset.load_graph()
        if algorithm_name is not None:
            dataset.convert_to_spatial(graph,file_name, scale_factor=scale_factor)

        for planner in planners:

            print(f"\nrunning {planner} on algorithm {algorithm_name} with variation {variation}")
            experiment = Timed_Experiment(graph, planner, 100, random_seed=42, verbose = False)
            experiment.run()
            print("Average Time: ", int(experiment.get_average_time()), "ns")
            print("Nr Extended: ", experiment.get_nr_extensions())
            print("Time per extension: ", int(experiment.get_average_extension_time()), "ns")
            
            print("Nr successful runs:", experiment.get_nr_successful_runs())	
            print("Average Successful Time: ", int(experiment.get_average_successful_time()), "ns")	 
            print("Nr Successful Extensions: ", experiment.get_nr_successful_extensions())	
            print("Time per successful extension: ", int(experiment.get_average_successful_extension_time()), "ns")	
            
            print("Nr unsuccessful runs:", experiment.get_nr_unsuccessful_runs())	
            print("Average Unsuccessful Time:", int(experiment.get_average_unsuccessful_time()), "ns")	 
            print("Nr Failed Extensions: ", experiment.get_nr_unsuccessful_extensions())	
            print("Time per failed extension: ", int(experiment.get_average_unsuccessful_extension_time()), "ns")
# Out:
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm None with variation 0
# Average Time:  416509816 ns
# Nr Extended:  3388818
# Time per extension:  12290 ns
# Nr successful runs: 19
# Average Successful Time:  467874136 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  15456 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 404461395 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11643 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm None with variation 0
# Average Time:  456377606 ns
# Nr Extended:  3388818
# Time per extension:  13467 ns
# Nr successful runs: 19
# Average Successful Time:  491203321 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  16226 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 448208611 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12903 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm None with variation 1
# Average Time:  399308717 ns
# Nr Extended:  3388818
# Time per extension:  11783 ns
# Nr successful runs: 19
# Average Successful Time:  420200078 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  13881 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 394408274 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11354 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm None with variation 1
# Average Time:  425782154 ns
# Nr Extended:  3388818
# Time per extension:  12564 ns
# Nr successful runs: 19
# Average Successful Time:  437760352 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  14461 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 422972453 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12176 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm None with variation 2
# Average Time:  370909482 ns
# Nr Extended:  3388818
# Time per extension:  10945 ns
# Nr successful runs: 19
# Average Successful Time:  404879394 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  13375 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 362941230 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10448 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm None with variation 2
# Average Time:  412282425 ns
# Nr Extended:  3388818
# Time per extension:  12165 ns
# Nr successful runs: 19
# Average Successful Time:  462168521 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  15267 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 400580748 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11531 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm None with variation 3
# Average Time:  371569259 ns
# Nr Extended:  3388818
# Time per extension:  10964 ns
# Nr successful runs: 19
# Average Successful Time:  417870400 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  13804 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 360708497 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10384 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm None with variation 3
# Average Time:  410400089 ns
# Nr Extended:  3388818
# Time per extension:  12110 ns
# Nr successful runs: 19
# Average Successful Time:  448395300 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  14812 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 401487632 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11558 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm None with variation 4
# Average Time:  392331298 ns
# Nr Extended:  3388818
# Time per extension:  11577 ns
# Nr successful runs: 19
# Average Successful Time:  409384821 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  13523 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 388331088 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11179 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm None with variation 4
# Average Time:  461411277 ns
# Nr Extended:  3388818
# Time per extension:  13615 ns
# Nr successful runs: 19
# Average Successful Time:  512565321 ns
# Nr Successful Extensions:  575155
# Time per successful extension:  16932 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 449412180 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12937 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm auto with variation 0
# Average Time:  349102145 ns
# Nr Extended:  3218843
# Time per extension:  10845 ns
# Nr successful runs: 19
# Average Successful Time:  234016894 ns
# Nr Successful Extensions:  405180
# Time per successful extension:  10973 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 376097450 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10827 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm auto with variation 0
# Average Time:  380950784 ns
# Nr Extended:  2842061
# Time per extension:  13404 ns
# Nr successful runs: 19
# Average Successful Time:  51601710 ns
# Nr Successful Extensions:  28398
# Time per successful extension:  34524 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 458205504 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13190 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm auto with variation 1
# Average Time:  360621349 ns
# Nr Extended:  3274321
# Time per extension:  11013 ns
# Nr successful runs: 19
# Average Successful Time:  271325157 ns
# Nr Successful Extensions:  460658
# Time per successful extension:  11190 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 381567369 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10984 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm auto with variation 1
# Average Time:  364134759 ns
# Nr Extended:  2852468
# Time per extension:  12765 ns
# Nr successful runs: 19
# Average Successful Time:  42271900 ns
# Nr Successful Extensions:  38805
# Time per successful extension:  20697 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 439633454 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12656 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm auto with variation 2
# Average Time:  363522495 ns
# Nr Extended:  3293419
# Time per extension:  11037 ns
# Nr successful runs: 19
# Average Successful Time:  289844463 ns
# Nr Successful Extensions:  479756
# Time per successful extension:  11478 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 380804996 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10962 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm auto with variation 2
# Average Time:  387632576 ns
# Nr Extended:  2858840
# Time per extension:  13559 ns
# Nr successful runs: 19
# Average Successful Time:  55112389 ns
# Nr Successful Extensions:  45177
# Time per successful extension:  23178 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 465631138 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13404 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm auto with variation 3
# Average Time:  368040912 ns
# Nr Extended:  3274679
# Time per extension:  11238 ns
# Nr successful runs: 19
# Average Successful Time:  279601936 ns
# Nr Successful Extensions:  461016
# Time per successful extension:  11523 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 388785856 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11192 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm auto with variation 3
# Average Time:  382894030 ns
# Nr Extended:  2875837
# Time per extension:  13314 ns
# Nr successful runs: 19
# Average Successful Time:  65612210 ns
# Nr Successful Extensions:  62174
# Time per successful extension:  20050 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 457318160 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13165 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm auto with variation 4
# Average Time:  370257692 ns
# Nr Extended:  3324951
# Time per extension:  11135 ns
# Nr successful runs: 19
# Average Successful Time:  310407957 ns
# Nr Successful Extensions:  511288
# Time per successful extension:  11535 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 384296518 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11063 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm auto with variation 4
# Average Time:  382612737 ns
# Nr Extended:  2897464
# Time per extension:  13205 ns
# Nr successful runs: 19
# Average Successful Time:  74589415 ns
# Nr Successful Extensions:  83801
# Time per successful extension:  16911 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 454865120 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13094 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm drl with variation 0
# Average Time:  365216811 ns
# Nr Extended:  3288192
# Time per extension:  11106 ns
# Nr successful runs: 19
# Average Successful Time:  282276052 ns
# Nr Successful Extensions:  474529
# Time per successful extension:  11302 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 384672050 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11073 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm drl with variation 0
# Average Time:  380538237 ns
# Nr Extended:  2872806
# Time per extension:  13246 ns
# Nr successful runs: 19
# Average Successful Time:  56490384 ns
# Nr Successful Extensions:  59143
# Time per successful extension:  18147 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 456549461 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13143 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm drl with variation 1
# Average Time:  362210664 ns
# Nr Extended:  3301889
# Time per extension:  10969 ns
# Nr successful runs: 19
# Average Successful Time:  298546173 ns
# Nr Successful Extensions:  488226
# Time per successful extension:  11618 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 377144309 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10857 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm drl with variation 1
# Average Time:  374028279 ns
# Nr Extended:  2853738
# Time per extension:  13106 ns
# Nr successful runs: 19
# Average Successful Time:  47327768 ns
# Nr Successful Extensions:  40075
# Time per successful extension:  22438 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 450661732 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12973 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm drl with variation 2
# Average Time:  356286006 ns
# Nr Extended:  3257531
# Time per extension:  10937 ns
# Nr successful runs: 19
# Average Successful Time:  282576063 ns
# Nr Successful Extensions:  443868
# Time per successful extension:  12095 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 373575992 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10754 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm drl with variation 2
# Average Time:  367570727 ns
# Nr Extended:  2845389
# Time per extension:  12918 ns
# Nr successful runs: 19
# Average Successful Time:  41089742 ns
# Nr Successful Extensions:  31726
# Time per successful extension:  24607 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 444152686 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12786 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm drl with variation 3
# Average Time:  355012160 ns
# Nr Extended:  3259777
# Time per extension:  10890 ns
# Nr successful runs: 19
# Average Successful Time:  265097178 ns
# Nr Successful Extensions:  446114
# Time per successful extension:  11290 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 376103328 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  10827 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm drl with variation 3
# Average Time:  379596992 ns
# Nr Extended:  2870461
# Time per extension:  13224 ns
# Nr successful runs: 19
# Average Successful Time:  54658073 ns
# Nr Successful Extensions:  56798
# Time per successful extension:  18284 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 455817232 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13122 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm drl with variation 4
# Average Time:  375573196 ns
# Nr Extended:  3367594
# Time per extension:  11152 ns
# Nr successful runs: 19
# Average Successful Time:  343698784 ns
# Nr Successful Extensions:  553931
# Time per successful extension:  11788 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 383049909 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  11027 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm drl with variation 4
# Average Time:  385327588 ns
# Nr Extended:  2869428
# Time per extension:  13428 ns
# Nr successful runs: 19
# Average Successful Time:  57353705 ns
# Nr Successful Extensions:  55765
# Time per successful extension:  19541 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 462259733 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13307 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm fruchterman_reingold with variation 0
# Average Time:  411047776 ns
# Nr Extended:  3243333
# Time per extension:  12673 ns
# Nr successful runs: 19
# Average Successful Time:  360036431 ns
# Nr Successful Extensions:  429670
# Time per successful extension:  15920 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 423013400 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12177 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm fruchterman_reingold with variation 0
# Average Time:  405850075 ns
# Nr Extended:  2850068
# Time per extension:  14240 ns
# Nr successful runs: 19
# Average Successful Time:  70565036 ns
# Nr Successful Extensions:  36405
# Time per successful extension:  36828 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 484497182 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13947 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm fruchterman_reingold with variation 1
# Average Time:  418885350 ns
# Nr Extended:  3293176
# Time per extension:  12719 ns
# Nr successful runs: 19
# Average Successful Time:  387886078 ns
# Nr Successful Extensions:  479513
# Time per successful extension:  15369 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 426156783 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12268 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm fruchterman_reingold with variation 1
# Average Time:  428549140 ns
# Nr Extended:  2859680
# Time per extension:  14985 ns
# Nr successful runs: 19
# Average Successful Time:  104505300 ns
# Nr Successful Extensions:  46017
# Time per successful extension:  43149 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 504559423 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  14525 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm fruchterman_reingold with variation 2
# Average Time:  426976616 ns
# Nr Extended:  3349097
# Time per extension:  12749 ns
# Nr successful runs: 19
# Average Successful Time:  431792157 ns
# Nr Successful Extensions:  535434
# Time per successful extension:  15322 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 425847044 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12259 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm fruchterman_reingold with variation 2
# Average Time:  425264020 ns
# Nr Extended:  2873033
# Time per extension:  14801 ns
# Nr successful runs: 19
# Average Successful Time:  102907300 ns
# Nr Successful Extensions:  59370
# Time per successful extension:  32933 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 500878559 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  14419 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm fruchterman_reingold with variation 3
# Average Time:  431324415 ns
# Nr Extended:  3353094
# Time per extension:  12863 ns
# Nr successful runs: 19
# Average Successful Time:  424498968 ns
# Nr Successful Extensions:  539431
# Time per successful extension:  14951 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 432925445 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12463 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm fruchterman_reingold with variation 3
# Average Time:  409251208 ns
# Nr Extended:  2877601
# Time per extension:  14221 ns
# Nr successful runs: 19
# Average Successful Time:  110146963 ns
# Nr Successful Extensions:  63938
# Time per successful extension:  32731 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 479411462 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  13801 ns
#
# running <class 'algorithms.dijkstra.Dijkstra'> on algorithm fruchterman_reingold with variation 4
# Average Time:  427989370 ns
# Nr Extended:  3310525
# Time per extension:  12928 ns
# Nr successful runs: 19
# Average Successful Time:  411478731 ns
# Nr Successful Extensions:  496862
# Time per successful extension:  15734 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 431862235 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  12432 ns
#
# running <class 'algorithms.a_star.A_Star'> on algorithm fruchterman_reingold with variation 4
# Average Time:  427420544 ns
# Nr Extended:  2876480
# Time per extension:  14859 ns
# Nr successful runs: 19
# Average Successful Time:  97601394 ns
# Nr Successful Extensions:  62817
# Time per successful extension:  29521 ns
# Nr unsuccessful runs: 81
# Average Unsuccessful Time: 504785529 ns
# Nr Failed Extensions:  2813663
# Time per failed extension:  14531 ns

# %% [markdown]
# **Results**
#
# The following table collects the average time over all experiments. Since the runs without layout algorithms are identical we will only pick one representation from them. All times are in ns.
#
# | Experiment | Dijkstra | Dijkstra (sucessful) | Dijkstra (failed) | A* | A* (successsful) | A* (failed) |
# | --- | --- | --- | --- | --- | --- | --- |
# | Benchmark 4| 392 ms| 409 ms | 388 ms | 461 ms | 513 ms | 449 ms |
# | auto 0 | **349 ms**  | 234 ms  | 376 ms | 380 ms | 51 ms | 458 ms |
# | auto 1 | 360 ms  | 271 ms  | 381 ms | **364** ms | 42 ms | 439 ms |
# | auto 2 | 363 ms  | 289 ms  | 380 ms | 387 ms | 55 ms | 465 ms |
# | auto 3 | 368 ms  | 279 ms  | 388 ms | 382 ms | 65 ms | 457 ms |
# | auto 4 | 370 ms  | 310 ms  | 384 ms | 382 ms | 74 ms | 454 ms |
# | drl 0 | 365 ms  | 282 ms  | 384 ms | 380 ms | 56 ms | 456 ms |
# | drl 1 | 362 ms  | 298 ms  | 377 ms | 374 ms | 47 ms | 450 ms |
# | drl 2 | 356 ms  | 282 ms  | 373 ms | 367 ms | 41 ms | 444 ms |
# | drl 3 | 355 ms  | 265 ms  | 376 ms | 379 ms | 54 ms | 455 ms |
# | drl 4 | 375 ms  | 343 ms  | 383 ms | 385 ms | 57 ms | 462 ms |
# | fruchterman_reingold 0 | 411 ms  | 360 ms | 423 ms | 405 ms | 70 ms | 484 ms |
# | fruchterman_reingold 1 | 418 ms  | 387 ms  | 426 ms | 428 ms | 104 ms | 504 ms |
# | fruchterman_reingold 2 | 426 ms  | 431 ms  | 425 ms | 425 ms | 102 ms | 500 ms |
# | fruchterman_reingold 3 | 431 ms  | 424 ms | 432 ms | 409 ms | 110 ms| 479 ms |
# | fruchterman_reingold 4 | 427 ms  | 411 ms  | 431 ms | 427 ms | 97 ms | 504 ms |
#
# The following table collects the average number of extended nodes over all experiments. Since the runs without layout algorithms are identical we will only pick one representation from them.
#
#
# | Experiment | Dijkstra | Dijkstra (sucessful) | Dijkstra (failed) | A* | A* (successsful) | A* (failed) |
# | --- | --- | --- | --- | --- | --- | --- |
# | Benchmark 4| 3.388.818 | 575.155 | 2.813.663 | 3.388.818 | 575.155 | 2.813.663 |
# | auto 0 | 3.218.843  | 405.180  | 2.813.663 | 2.842.061 | 28.398 | 2.813.663 |
# | auto 1 | 3.274.321  | 460.658  | 2.813.663 | 2.852.468 | 38.805 | 2.813.663 |
# | auto 2 | 3.293.419  | 479.756  | 2.813.663 | 2.858.840 | 45.177 | 2.813.663 |
# | auto 3 | 3.274.679  | 461.016  | 2.813.663 | 2.875.837 | 62.174 | 2.813.663 |
# | auto 4 | 3.324.951  | 511.288  | 2.813.663 | 2.897.464 | 83.801 | 2.813.663 |
# | drl 0 | 3.288.192 | 474.529 | 2.813.663 | 2.872.806 | 59.143 | 2.813.663 |
# | drl 1 | 3.301.889 | 488.226 | 2.813.663 | 2.853.738 | 40.075 | 2.813.663 |
# | drl 2 | 3.257.531 | 443.868 | 2.813.663 | 2.845.389 | 31.726 | 2.813.663 |
# | drl 3 | 3.259.777 | 446.114 | 2.813.663 | 2.870.461 | 56.798 | 2.813.663 |
# | drl 4 | 3.367.594 | 553.931 | 2.813.663 | 2.869.428 | 55.765 | 2.813.663 |
# | fruchterman_reingold 0 | 3.243.333 | 429.670 | 2.813.663 | 2.850.068 | 36.405 | 2.813.663 |
# | fruchterman_reingold 1 | 3.293.176 | 479.513 | 2.813.663 | 2.859.680 | 46.017 | 2.813.663 |
# | fruchterman_reingold 2 | 3.349.097 | 535.434 | 2.813.663 | 2.873.033 | 59.370 | 2.813.663 |
# | fruchterman_reingold 3 | 3.353.094 | 539.431 | 2.813.663 | 2.877.601 | 63.938 | 2.813.663 |
# | fruchterman_reingold 4 | 3.310.525 | 496.862 | 2.813.663 | 2.876.480 | 62.817 | 2.813.663 |

# %% [markdown]
# **Discussion**
#
# In the tables above, we can see that "auto" and "drl" outperform fruchterman_reingold and the Benchmark on this task. Indeed, fruchterman_reingold is worse in execution time for dijkstra than the original graph but slightly better for A*.
# For our continued experiments we will use the run with the lowest score. For Dijkstra this is auto_0 and for A* this is auto_1. We will use auto_0 as the run with the overall lowest score.
#
# While this was not our main concern, the results also show some differences in how the coordinates affect Dijkstra's algorithm and A*.
#
# A* significantly outperforms Dijkstra in cases where a path exist. For "auto" and "dlr", A* is around 50 ms, while Dijkstra takes around 250 to 300 ms. This can be attributed by A* being able to make efficient use of the annotated coordinates. This can be seen clearly in the number of extended nodes.
#
# In cases where no path exists, Dijkstra's algorithm is usually faster. This can be attributed to the lower algorithmic complexity of Dijkstra's algorithm.
#
# Over all cases, the two algorithms perform similarly. This is likely due to the fact that the majority of nodes are not connected via a path, meaning the advantage of A* doesn't come into play on enough cases to matter.
